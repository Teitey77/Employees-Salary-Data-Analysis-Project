# %% [markdown]
# ### Project Background

# %%
# This prpject dataset is about san francisco city employees salaries

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\adams\OneDrive\Desktop\Python Projects\Python Data Analysis\Data Thinkers py projects\Project 2_Salaries\Salaries.csv")
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ### Display the top 10 rows of the dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# ### Check the last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %% [markdown]
# ### Find the shape of the dataframe (number of rows and columns)

# %%
print(df.shape)
print("number of rows", df.shape[0])
print("number of columns", df.shape[1])
# Out:
# (148654, 13)
# number of rows 148654
# number of columns 13

# %% [markdown]
#  ### Getting information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# ### Check null values in the dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# ### Drop irrelevant columns

# %%
df1 = df.drop(["Id", "Notes", "Status"], axis=1)

# %%
df1.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency'],
#       dtype='object')

# %% [markdown]
# ### Get overall statistics about the dataframe

# %%
df1.describe(include="all")
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        148654            148654  148045.000000  148650.000000
# unique       110811              2159            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             13              7036            NaN            NaN
# mean            NaN               NaN   66325.448840    5066.059886
# std             NaN               NaN   42764.635495   11454.380559
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   33588.200000       0.000000
# 50%             NaN               NaN   65007.450000       0.000000
# 75%             NaN               NaN   94691.050000    4658.175000
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay       Benefits       TotalPay  TotalPayBenefits  \
# count   148650.000000  112491.000000  148654.000000     148654.000000
# ...

# %% [markdown]
# ### Find occurence of the employee names (Top 7)

# %%
#df1["EmployeeName"].nunique()
df1["EmployeeName"].value_counts().head(7)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# KEVIN LEE        9
# Michael Wong     9
# Name: count, dtype: int64

# %% [markdown]
# ### Find the number of Unique Job Titles

# %%
df1["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
unique_Job_Title = df1["JobTitle"].unique()

for x in unique_Job_Title:
    print(x)
# Out:
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# CAPTAIN III (POLICE DEPARTMENT)
# WIRE ROPE CABLE MAINTENANCE MECHANIC
# DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ASSISTANT DEPUTY CHIEF II
# BATTALION CHIEF, (FIRE DEPARTMENT)
# DEPUTY DIRECTOR OF INVESTMENTS
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# EXECUTIVE CONTRACT EMPLOYEE
# DEPARTMENT HEAD V
# COMMANDER III, (POLICE DEPARTMENT)
# CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# ASSISTANT MEDICAL EXAMINER
# CAPTAIN, FIRE SUPPRESSION
# CHIEF OF POLICE
# DEPUTY CHIEF III (POLICE DEPARTMENT)
# INSPECTOR III, (POLICE DEPARTMENT)
# ELECTRONIC MAINTENANCE TECHNICIAN
# ADMINISTRATOR, SFGH MEDICAL CENTER
# LIEUTENANT III (POLICE DEPARTMENT)
# FIREFIGHTER
# NURSING SUPERVISOR PSYCHIATRIC
# MAYOR
# LIEUTENANT, FIRE DEPARTMENT
# INCIDENT SUPPORT SPECIALIST
# ANESTHETIST
# DISTRICT ATTORNEY
# ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR
# PORT DIRECTOR
# ...

# %%
df1["JobTitle"].nunique()
# Out:
# 2159

# %% [markdown]
# ### Total number of Job titles contatining the word "captain"

# %%
len(df1[df1["JobTitle"].str.contains("captain", case=False)])
# Out:
# 552

# %%
df1[df1["JobTitle"].str.contains("captain", case=False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# Agency              552
# dtype: int64

# %% [markdown]
# ### Disply all the employee names from the fire department

# %%
df1[df1["JobTitle"].str.contains("Fire", case=False)]["EmployeeName"]
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
Frire_emp_name = df1[df1["JobTitle"].str.contains("Fire", case=False)]["EmployeeName"]

for x in Frire_emp_name:
    print(x)
# Out:
# PATRICK GARDNER
# ALSON LEE
# MICHAEL MORRIS
# JOANNE HAYES-WHITE
# ARTHUR KENNEY
# DAVID FRANKLIN
# MARTY ROSS
# GEORGE GARCIA
# VICTOR WYRSCH
# JOSEPH DRISCOLL
# JOHN HANLEY
# RAYMOND GUZMAN
# MONICA FIELDS
# JOSE VELO
# BRENDAN WARD
# MICHAEL THOMPSON
# THOMAS ABBOTT
# THOMAS SIRAGUSA
# MICHAEL THOMPSON
# BRYAN RUBENSTEIN
# KEN YEE
# KIRK RICHARDSON
# MICHAEL ROLOVICH
# DARRYL HUNTER
# KENNETH SMITH
# CHARLES CRANE
# ROBERT POSTEL
# EDWARD ROLAND
# RICHARD BUSALACCHI
# KEVIN BURKE
# BERT REYES
# MICHAEL DELANE
# EDUARDO GONZALEZ
# ROBERT WINSLOW
# LORRIE KALOS
# JONATHAN BAXTER
# MICHAEL BRYANT
# MARY TSE
# MARK GONZALES
# PETE FAY JR
# REX HALE
# KEVIN SMITH
# GREGORY STANGLAND
# KEVIN TAYLOR
# ERIKA HOO
# LAUIFI SEUMAALA
# PATRIC STEELE
# MICHAEL WALSH
# SAMSON LAI
# SCOTT SCHOLZEN
# KHAIRUL ALI
# MICHAEL CASTAGNOLA
# SEAN BONETTI
# JOHN HICKEY
# GLEN KOJIMOTO
# EDWARD CHU
# SOFIA MATHEWS
# EDMUND DEA
# ZACHARY PUMPHREY
# MARK CASTAGNOLA
# LUIS IBARRA-RIVERA
# DONNIE HORNBUCKLE
# ...

# %% [markdown]
# ### Find Max/MIN/AVG BasePay

# %%
df1["BasePay"].describe()
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
print(df1["BasePay"].max())
print(df1["BasePay"].min())
print(df1["BasePay"].mean())
# Out:
# 319275.01
# -166.01
# 66325.4488404877

# %%
df1["EmployeeName"] = df1["EmployeeName"].replace("Not provided", np.nan)

# %% [markdown]
# ### Drop rows having 5 missing values

# %%
df1.drop(df1[df1.isnull().sum(axis=1) == 5].index, axis=0, inplace=True)

# %%
# you have to specifically add index so it can base on this index to remove rows based on your specified condition

#df1[df1.isnull().sum(axis=1) == 5]
#df1[df1.isnull().sum(axis=1) == 5].index
# Out:
# Index([148646, 148650, 148651, 148652], dtype='int64')

# %%
df1.isnull().sum(axis=1)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 148645    0
# 148647    0
# 148648    0
# 148649    0
# 148653    0
# Length: 148650, dtype: int64

# %% [markdown]
# ### Find the Job Title of "ALBERT PARDINI" nb: all caps

# %%
df1[df1["EmployeeName"] == "ALBERT PARDINI"]
#df1[df1["EmployeeName"] == "ALBERT PARDINI"][["JobTitle"]]
# Out:
#      EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 2  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
#
#    OtherPay  Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 2   16452.6       NaN  335279.91         335279.91  2011  San Francisco

# %%
df1[df1["EmployeeName"].str.contains("pardini", case=False)]
# Out:
#              EmployeeName                         JobTitle    BasePay  \
# 2          ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 1705        KEVIN PARDINI      LIEUTENANT, FIRE DEPARTMENT  123105.03
# 16665       PETER PARDINI                SENIOR ACCOUNTANT   72463.98
# 36519      Albert Pardini                        Captain 3  196265.04
# 37538       Kevin Pardini     Lieutenant, Fire Suppression  140183.63
# 52607       Peter Pardini                    Accountant II   74165.04
# 73132    Albert A Pardini                        Captain 3  206820.01
# 73887     Kevin J Pardini        Captain, Fire Suppression  153763.84
# 89607   Michael A Pardini                   Police Officer   78591.00
# 89667     Peter A Pardini                    Accountant II   79339.55
# 110934   Albert A Pardini                        Captain 3  188436.01
# 111245    Kevin J Pardini        Captain, Fire Suppression  149531.76
# ...

# %% [markdown]
# ### How much does ALBERT PARDINI MAKE (include Benefits)

# %%
df1[df1["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### Display the name of the peroson having the highest BasePay

# %%
df1[df1["BasePay"].max() == df1["BasePay"]]
# Out:
#          EmployeeName         JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01          0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year         Agency
# 72925  86533.21  339282.07         425815.28  2013  San Francisco

# %%
df1[df1["BasePay"].max() == df1["BasePay"]]["EmployeeName"]
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# ### Find average BasePay of all emplyoees Per Year

# %%
df1.groupby("Year")["BasePay"].mean()
#df1.groupby("Year").mean()["BasePay"]
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### Find avearge BasePay of all employee per Job title

# %%
df1.groupby("JobTitle")["BasePay"].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2158, dtype: float64

# %% [markdown]
# ### Find the average BasePay of employee having job title ACcountant

# %%
#These method might not be the best since it does not match exactly "accountant"
#method1
##df1[df1["JobTitle"].str.contains("accountant", case=False)][["BasePay"]].mean()
#method2
##acc_dat = df1[df1["JobTitle"].str.contains("accountant", case=False)]
##acc_dat["BasePay"].mean()
# Out:
# BasePay    72245.572411
# dtype: float64

# %%
#method3
df1[df1["JobTitle"]=="ACCOUNTANT"]["BasePay"].mean()
# Out:
# 46643.172

# %% [markdown]
# ### Find the top 7 most common Jobs

# %%
df1["JobTitle"].value_counts().head(7)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Name: count, dtype: int64
